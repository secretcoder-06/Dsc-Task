# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("2021 New Coder Survey.csv",low_memory=False)

# %%
df.head()
# Out:
#            Timestamp 1. What is your biggest reason for learning to code?  \
# 0  7/1/2021 10:10:23                       To succeed in current career
# 1  7/1/2021 10:31:01                                  To change careers
# 2  7/1/2021 10:42:31                                  To change careers
# 3  7/1/2021 11:06:43                                         As a hobby
# 4  7/1/2021 11:14:31                         To start your first career
#
#   2. What methods have you used to learn about coding? Please select all that apply.  \
# 0  Online resources, Books, In-person bootcamps, ...
# 1          Online resources, Books, Online bootcamps
# 2  Online resources, Books, Hackathons, Meetup.co...
# 3                            Online resources, Books
# 4          Online resources, Books, Online bootcamps
#
#   3. Which online learning resources have you found helpful? Please select all that apply.  \
# 0  freeCodeCamp, Mozilla Developer Network (MDN),...
# ...

# %% [markdown]
# List all column names

# %% [markdown]
# Check the structure and summary statistics

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18126 entries, 0 to 18125
# Data columns (total 63 columns):
#  #   Column                                                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                                                      --------------  -----
#  0   Timestamp                                                                                                                                                                   18126 non-null  object
#  1   1. What is your biggest reason for learning to code?                                                                                                                        17991 non-null  object
# ...

# %% [markdown]
# Check data types and count missing values for each column

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                              0
# 1. What is your biggest reason for learning to code?                                                                                 135
# 2. What methods have you used to learn about coding? Please select all that apply.                                                   289
# 3. Which online learning resources have you found helpful? Please select all that apply.                                             752
# 4. If you have attended in-person coding-related events before, which ones have you found helpful? Please select all that apply.    1539
#                                                                                                                                     ...
# 45. Please tell us how satisfied you are with each of these following aspects of your present job [Weekly workload]                 5904
# ...

# %% [markdown]
# Plot histogram for a numerical feature

# %%
plt.figure(figsize=(12, 6))
df['22. About how much money did you earn last year from any job or employment (in US Dollars)? '].value_counts().plot(kind='bar')
plt.xlabel('Annual Salary (USD)')
plt.ylabel('Frequency')
plt.title('Distribution of Annual Salary')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Analyze categorical features with count plots

# %%
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.bar(['No', 'Yes'], df['37. Do you financially support any dependents, older relatives or relatives with disabilities?'].value_counts())
plt.xlabel('Financially Supports Dependents')
plt.ylabel('Count')
plt.title('Distribution of Financial Support for Dependents')
plt.show()

# %% [markdown]
# the histograms for 'Hours Spent Learning per Week.

# %%
plt.figure(figsize=(10, 6))
df['7. About how many hours do you spend learning each week?'].hist(bins=20)
plt.xlabel('Hours per Week')
plt.ylabel('Frequency')
plt.title('Distribution of Hours Spent Learning per Week')
plt.show()

# %% [markdown]
# the histograms for 'Hours Spent Learning as per Age.

# %%
plt.figure(figsize=(10, 6))
df['23. How old are you?'].hist(bins=20)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()
